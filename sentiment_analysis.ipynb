# %%
# !pip install transformers

# %%
import pandas as pd

# %%
from transformers import pipeline

# %%
data = pd.read_excel('Data Scientist test kit_updated.xlsx')

# %%
data["full_text_len"] = data['Full Text'].apply(lambda x: len(x))

# %%
data[data["full_text_len"]>512].shape
# Out:
# (45, 16)

# %%
pipe = pipeline(task='sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
def slice_text(text, chunk_size):
    chunks = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]
    return chunks

# %%
from collections import Counter

# %%
def predictions(text):
  chunks = slice_text(text, 512)
  pred_list = [pipe(item)[0].get('label') for item in chunks]
  value_counts = Counter(pred_list)
  max_value = max(value_counts, key=lambda k: value_counts[k])
  return max_value

# %%
data['predictions'] = data['Full Text'].apply(lambda x: predictions(x))

# %%
data[['predictions','Full Text']].head()
# Out:
#   predictions                                          Full Text
# 0    NEGATIVE  I've been using Retirides.025 for more than a ...
# 1    NEGATIVE  It was weird because I don’t get breakouts, bu...
# 2    POSITIVE        Thank you! Can’t wait to see your progress!
# 3    POSITIVE  Literally cannot see anything wrong with them....
# 4    POSITIVE  I was advised if you’re using tret for anti-ag...

# %%
data.to_excel("Predicted_data_infovision.xlsx")
